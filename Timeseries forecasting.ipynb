# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.api import ExponentialSmoothing
import datetime

df = pd.read_csv("video_games_sales.csv")
df.sort_values(by='Year_of_Release', ascending = True)
train=df[0:10] 
test=df[8000:] 
df.index = df.Year_of_Release 
train.index = train.Global_Sales 
test.index = test.Global_Sales 
train.Year_of_Release.plot(figsize=(30,8), title= 'sales', fontsize=14)
# test.Year_of_Release.plot(figsize=(30,8), title= 'sales', fontsize=14)

# %%
#Naive
